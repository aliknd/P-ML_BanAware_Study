# %%
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the dataset
data = pd.read_csv("10.csv")

# Separate data into different dataframes based on data types
spo2_data = data[data['data_type'] == 'spo2'].copy()
heart_rate_data = data[data['data_type'] == 'hr'].copy()
steps_data = data[data['data_type'] == 'steps'].copy()
hrv_data = data[data['data_type'] == 'hrv'].copy()
br_data = data[data['data_type'] == 'br'].copy()
sleep_data = data[data['data_type'] == 'sleep'].copy()

# Convert timestamps to datetime format for each dataframe
spo2_data['time'] = pd.to_datetime(spo2_data['time'])
heart_rate_data['time'] = pd.to_datetime(heart_rate_data['time'])
steps_data['time'] = pd.to_datetime(steps_data['time'])
hrv_data['time'] = pd.to_datetime(hrv_data['time'])
br_data['time'] = pd.to_datetime(br_data['time'])
sleep_data['time'] = pd.to_datetime(sleep_data['time'])

# Sort dataframes based on time and their respective formats
spo2_data.sort_values(by='time', inplace=True)
heart_rate_data.sort_values(by='time', inplace=True)
steps_data.sort_values(by='time', inplace=True)
hrv_data.sort_values(by='time', inplace=True)
br_data.sort_values(by='time', inplace=True)
sleep_data.sort_values(by='time', inplace=True)

# %%
heart_rate_data=heart_rate_data[['value', 'time']]

# %%
heart_rate_data
# Out:
#       value                      time
# 2        70 2023-11-23 00:00:00+00:00
# 3        75 2023-11-23 00:01:00+00:00
# 4        78 2023-11-23 00:02:00+00:00
# 5        74 2023-11-23 00:03:00+00:00
# 6        76 2023-11-23 00:04:00+00:00
# ...     ...                       ...
# 53937    62 2023-12-20 23:55:00+00:00
# 53938    63 2023-12-20 23:56:00+00:00
# 53939    63 2023-12-20 23:57:00+00:00
# 53940    62 2023-12-20 23:58:00+00:00
# 53941    63 2023-12-20 23:59:00+00:00
#
# [38041 rows x 2 columns]

# %%
steps_data=steps_data[['value', 'time']]

# %%
steps_data
# Out:
#       value                      time
# 39       16 2023-11-23 00:36:00+00:00
# 73        7 2023-11-23 01:10:00+00:00
# 76        4 2023-11-23 01:12:00+00:00
# 78       11 2023-11-23 01:13:00+00:00
# 525      35 2023-11-23 06:09:00+00:00
# ...     ...                       ...
# 53887    25 2023-12-20 23:15:00+00:00
# 53890    23 2023-12-20 23:16:00+00:00
# 53891     5 2023-12-20 23:17:00+00:00
# 53896     4 2023-12-20 23:20:00+00:00
# 53908     7 2023-12-20 23:31:00+00:00
#
# [5810 rows x 2 columns]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load craving and non-craving data
craving_data = pd.read_csv('ID10_Crave.csv')
non_craving_data = pd.read_csv('ID10_None.csv')

# Filter rows with 'Carrot' in the substance_fruit_label column
craving_data = craving_data[craving_data['substance_fruit_label'] == 'Nectarine']

# Convert timestamps to ensure they are timezone-naive
craving_data['hawaii_createdat_time'] = pd.to_datetime(craving_data['hawaii_createdat_time']).dt.tz_localize(None)
non_craving_data['hawaii_createdat_time'] = pd.to_datetime(non_craving_data['hawaii_createdat_time']).dt.tz_localize(None)

# Ensure heart rate and steps data use the same timezone-naive datetime index
heart_rate_data['time'] = pd.to_datetime(heart_rate_data['time']).dt.tz_localize(None)
steps_data['time'] = pd.to_datetime(steps_data['time']).dt.tz_localize(None)

heart_rate_data.set_index('time', inplace=True)
steps_data.set_index('time', inplace=True)

# Convert the 'value' column to numeric, coercing errors
heart_rate_data['value'] = pd.to_numeric(heart_rate_data['value'], errors='coerce')
steps_data['value'] = pd.to_numeric(steps_data['value'], errors='coerce')

# Remove duplicate timestamps
heart_rate_data = heart_rate_data[~heart_rate_data.index.duplicated(keep='first')]
steps_data = steps_data[~steps_data.index.duplicated(keep='first')]

# Reindex and forward fill to handle missing data
heart_rate_data = heart_rate_data.reindex(pd.date_range(start=heart_rate_data.index.min(), end=heart_rate_data.index.max(), freq='min'), method='ffill')
steps_data = steps_data.reindex(pd.date_range(start=steps_data.index.min(), end=steps_data.index.max(), freq='min'), method='ffill').fillna(0)

# Initialize the StandardScaler
scaler = StandardScaler()

def process_label_data(label_data, heart_rate_data, steps_data, scaler):
    results = []
    for _, row in label_data.iterrows():
        timestamp = row['hawaii_createdat_time']
        lower_bound = timestamp - pd.Timedelta(hours=1)
        upper_bound = timestamp + pd.Timedelta(hours=1)

        # Extract data within the window
        hr_window = heart_rate_data.loc[lower_bound:upper_bound]
        steps_window = steps_data.loc[lower_bound:upper_bound]

        # Resample and calculate mean every 4 minutes to get 30 points
        hr_means = hr_window.resample('4min').mean().iloc[:30]  # Ensure 30 data points
        steps_means = steps_window.resample('4min').mean().iloc[:30]

        if len(hr_means) == 30 and len(steps_means) == 30:
            # Standardize the means
            hr_scaled = scaler.fit_transform(hr_means.values.reshape(-1, 1))
            steps_scaled = scaler.fit_transform(steps_means.values.reshape(-1, 1))

            results.append({
                'timestamp': timestamp,
                'heart_rate_means': hr_scaled.flatten().tolist(),
                'steps_means': steps_scaled.flatten().tolist()
            })

    return pd.DataFrame(results)

# Process craving and non-craving labels
craving_features = process_label_data(craving_data, heart_rate_data, steps_data, scaler)
non_craving_features = process_label_data(non_craving_data, heart_rate_data, steps_data, scaler)

# Output results
print("Craving Features Data:")
print(craving_features.head())
print("Non-Craving Features Data:")
print(non_craving_features.head())
# Out:
# Craving Features Data:
#             timestamp                                   heart_rate_means  \
# 0 2023-11-27 17:06:54  [-0.4077798470617748, -0.04921480912814488, 0....
# 1 2023-11-28 15:09:42  [1.1164115773804473, 0.2702891187342125, 1.045...
# 2 2023-12-01 22:15:58  [0.7188871800370492, 0.26071932629568195, 1.20...
# 3 2023-12-03 16:03:29  [-0.5342255889956353, -0.7594260714762308, -0....
# 4 2023-12-03 18:00:44  [-0.1947903537684357, -0.0837459715726514, -0....
#
#                                          steps_means
# 0  [1.0239999054945357, 0.44762568968255284, -0.5...
# 1  [1.1358660206519509, 1.1358660206519509, 1.135...
# 2  [0.657301726469514, 0.4913630016946017, 1.5976...
# 3  [-0.467168836263489, -0.467168836263489, -0.46...
# 4  [-0.2777670839733358, -0.3793891878660196, -0....
# Non-Craving Features Data:
#             timestamp                                   heart_rate_means  \
# 0 2023-11-28 15:09:42  [1.1164115773804473, 0.2702891187342125, 1.045...
# 1 2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# 2 2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# 3 2023-11-29 13:46:17  [0.5720173895929694, 0.10400316174417626, 0.57...
# 4 2023-11-29 17:02:21  [-0.7464240342806893, -1.7322670984249973, -0....
#
#                                          steps_means
# 0  [1.1358660206519509, 1.1358660206519509, 1.135...
# 1  [0.40009983687523415, 0.40009983687523415, 0.4...
# 2  [0.40009983687523415, 0.40009983687523415, 0.4...
# 3  [-1.8901033586340465, -1.8901033586340465, -1....
# 4  [-0.8240793061668402, -0.8240793061668402, -0....

# %%
# Print the shape of the craving features data
print("Shape of Craving Features Data:", craving_features.shape)

# Print the shape of the non-craving features data
print("Shape of Non-Craving Features Data:", non_craving_features.shape)
# Out:
# Shape of Craving Features Data: (25, 3)
# Shape of Non-Craving Features Data: (61, 3)

# %%
import pandas as pd

# Adding label columns
craving_features['state'] = 'crave'
craving_features['state_val'] = 1

non_craving_features['state'] = 'non_crave'
non_craving_features['state_val'] = 0

# Combining the dataframes
combined_data = pd.concat([craving_features, non_craving_features])

# Converting timestamps to datetime and sorting
combined_data['timestamp'] = pd.to_datetime(combined_data['timestamp'])
combined_data_sorted = combined_data.sort_values(by='timestamp').reset_index(drop=True)

# This combined_data_sorted is now ready for use in your neural network model
print(combined_data_sorted)
# Out:
#              timestamp                                   heart_rate_means  \
# 0  2023-11-27 17:06:54  [-0.4077798470617748, -0.04921480912814488, 0....
# 1  2023-11-28 15:09:42  [1.1164115773804473, 0.2702891187342125, 1.045...
# 2  2023-11-28 15:09:42  [1.1164115773804473, 0.2702891187342125, 1.045...
# 3  2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# 4  2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# ..                 ...                                                ...
# 81 2023-12-19 21:04:47  [2.7477021384420746, 3.377959771807056, 2.4823...
# 82 2023-12-19 21:04:47  [2.7477021384420746, 3.377959771807056, 2.4823...
# 83 2023-12-20 15:47:33  [-0.5898899676932021, -0.5898899676932021, -0....
# 84 2023-12-20 18:42:51  [0.06869206174208, 0.5838825248076779, 0.47348...
# 85 2023-12-20 18:42:51  [0.06869206174208, 0.5838825248076779, 0.47348...
#
#                                           steps_means      state  state_val
# 0   [1.0239999054945357, 0.44762568968255284, -0.5...      crave          1
# 1   [1.1358660206519509, 1.1358660206519509, 1.135...  non_crave          0
# 2   [1.1358660206519509, 1.1358660206519509, 1.135...      crave          1
# 3   [0.40009983687523415, 0.40009983687523415, 0.4...  non_crave          0
# 4   [0.40009983687523415, 0.40009983687523415, 0.4...  non_crave          0
# ..                                                ...        ...        ...
# 81  [-1.239678371558235, -1.239678371558235, -2.90...  non_crave          0
# 82  [-1.239678371558235, -1.239678371558235, -2.90...      crave          1
# 83  [-0.654429794750433, -0.654429794750433, -0.65...      crave          1
# 84  [1.1185452796660895, -0.2411913844721381, 1.32...  non_crave          0
# 85  [1.1185452796660895, -0.2411913844721381, 1.32...  non_crave          0
#
# [86 rows x 5 columns]

# %%
import tensorflow as tf

# Load pretrained models
encoder_hr = tf.keras.models.load_model('heart_rate_encoder')
encoder_steps = tf.keras.models.load_model('steps_encoder')
# Out:
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:178: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np

# Function to generate embeddings using the loaded models
def generate_embeddings(hr_data, steps_data, encoder_hr, encoder_steps):
    # Convert lists to numpy arrays and ensure they are in the correct shape
    hr_data = np.array(hr_data.tolist())
    steps_data = np.array(steps_data.tolist())

    # Reshape data if required by the model, assuming the model expects shape (samples, features)
    if hr_data.ndim == 1:
        hr_data = hr_data.reshape(-1, 1)
    if steps_data.ndim == 1:
        steps_data = steps_data.reshape(-1, 1)

    # Generate embeddings
    hr_embeddings = encoder_hr.predict(hr_data)
    steps_embeddings = encoder_steps.predict(steps_data)

    return hr_embeddings, steps_embeddings

# Use the function with your data
hr_embeddings, steps_embeddings = generate_embeddings(
    combined_data_sorted['heart_rate_means'],
    combined_data_sorted['steps_means'],
    encoder_hr,
    encoder_steps
)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 3ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, auc
from sklearn.metrics import recall_score, precision_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

# Combine the heart rate and steps embeddings
combined_embeddings = np.concatenate([hr_embeddings, steps_embeddings], axis=1)

# Labels from your existing DataFrame
labels = combined_data_sorted['state_val'].values

# Calculate class weights
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(combined_embeddings, labels, test_size=0.2, random_state=42)

# Define the model with regularization and batch normalization
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(16, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy', Precision(), Recall()])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    class_weight=class_weight_dict,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate thresholds on training set
probabilities_train = model.predict(X_train)
thresholds = np.arange(0, 1.01, 0.01)

# Store training results
training_results = []

print("\nTraining Set Evaluation:")
for threshold in thresholds:
    predicted_classes = (probabilities_train > threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_train, predicted_classes).ravel()
    recall = tp / (tp + fn)  # Sensitivity
    specificity = tn / (tn + fp)  # Specificity
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    training_results.append((threshold, recall, specificity, accuracy))
    print(f"Threshold: {threshold:.2f}, Sensitivity: {recall:.2f}, Specificity: {specificity:.2f}, Accuracy: {accuracy:.2f}")

# Convert training results to DataFrame for easy viewing
training_results_df = pd.DataFrame(training_results, columns=['Threshold', 'Sensitivity', 'Specificity', 'Accuracy'])

# Select best threshold based on a specific criterion
# Here, we select the threshold with the highest sensitivity while keeping specificity above 0.5
best_threshold_row = training_results_df[(training_results_df['Sensitivity'] > 0.9) & (training_results_df['Specificity'] > 0.5)]
if not best_threshold_row.empty:
    best_threshold = best_threshold_row.iloc[0]['Threshold']
else:
    best_threshold = 0.5  # Default threshold if criteria is not met

print(f"\nBest Threshold from Training Set: {best_threshold}")

# Evaluate the best threshold on the test set
probabilities_test = model.predict(X_test)
predicted_classes_test = (probabilities_test > best_threshold).astype(int)
tn, fp, fn, tp = confusion_matrix(y_test, predicted_classes_test).ravel()
recall_test = tp / (tp + fn)  # Sensitivity
specificity_test = tn / (tn + fp)  # Specificity
accuracy_test = (tp + tn) / (tp + tn + fp + fn)

print(f"\nTest Set Evaluation at Best Threshold ({best_threshold}):")
print(f"Sensitivity: {recall_test:.2f}")
print(f"Specificity: {specificity_test:.2f}")
print(f"Accuracy: {accuracy_test:.2f}")

# Evaluate thresholds on test set
print("\nTest Set Evaluation for Each Threshold:")
test_results = []

for threshold in thresholds:
    predicted_classes = (probabilities_test > threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, predicted_classes).ravel()
    recall = tp / (tp + fn)  # Sensitivity
    specificity = tn / (tn + fp)  # Specificity
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    test_results.append((threshold, recall, specificity, accuracy))
    print(f"Threshold: {threshold:.2f}, Sensitivity: {recall:.2f}, Specificity: {specificity:.2f}, Accuracy: {accuracy:.2f}")

# Convert test results to DataFrame for easy viewing
test_results_df = pd.DataFrame(test_results, columns=['Threshold', 'Sensitivity', 'Specificity', 'Accuracy'])

# Plot the training results
plt.figure(figsize=(12, 6))
plt.plot(training_results_df['Threshold'], training_results_df['Sensitivity'], label='Sensitivity (Train)')
plt.plot(training_results_df['Threshold'], training_results_df['Specificity'], label='Specificity (Train)')
plt.plot(training_results_df['Threshold'], training_results_df['Accuracy'], label='Accuracy (Train)')
plt.plot(test_results_df['Threshold'], test_results_df['Sensitivity'], label='Sensitivity (Test)', linestyle='dashed')
plt.plot(test_results_df['Threshold'], test_results_df['Specificity'], label='Specificity (Test)', linestyle='dashed')
plt.plot(test_results_df['Threshold'], test_results_df['Accuracy'], label='Accuracy (Test)', linestyle='dashed')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Sensitivity, Specificity, and Accuracy vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 3s 170ms/step - loss: 2.4467 - accuracy: 0.2787 - precision: 0.2041 - recall: 0.6667 - val_loss: 2.2911 - val_accuracy: 0.5714 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 2/50
# 4/4 [==============================] - 0s 21ms/step - loss: 2.4554 - accuracy: 0.2951 - precision: 0.2083 - recall: 0.6667 - val_loss: 2.2313 - val_accuracy: 0.5714 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 3/50
# 4/4 [==============================] - 0s 40ms/step - loss: 2.2222 - accuracy: 0.4098 - precision: 0.2558 - recall: 0.7333 - val_loss: 2.1740 - val_accuracy: 0.8571 - val_precision: 1.0000 - val_recall: 0.7500
# Epoch 4/50
# 4/4 [==============================] - 0s 25ms/step - loss: 2.1570 - accuracy: 0.4590 - precision: 0.2750 - recall: 0.7333 - val_loss: 2.1191 - val_accuracy: 0.5714 - val_precision: 1.0000 - val_recall: 0.2500
# Epoch 5/50
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1274 - accuracy: 0.4262 - precision: 0.2619 - recall: 0.7333 - val_loss: 2.0668 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/50
# 4/4 [==============================] - 0s 21ms/step - loss: 2.1087 - accuracy: 0.3607 - precision: 0.2273 - recall: 0.6667 - val_loss: 2.0184 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.9537 - accuracy: 0.5410 - precision: 0.3143 - recall: 0.7333 - val_loss: 1.9730 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 4/4 [==============================] - 0s 20ms/step - loss: 2.0097 - accuracy: 0.4590 - precision: 0.2632 - recall: 0.6667 - val_loss: 1.9306 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.9721 - accuracy: 0.4098 - precision: 0.2558 - recall: 0.7333 - val_loss: 1.8906 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.8490 - accuracy: 0.4426 - precision: 0.2564 - recall: 0.6667 - val_loss: 1.8530 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.8348 - accuracy: 0.4426 - precision: 0.2432 - recall: 0.6000 - val_loss: 1.8177 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7704 - accuracy: 0.4754 - precision: 0.2703 - recall: 0.6667 - val_loss: 1.7844 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/50
# 4/4 [==============================] - 0s 23ms/step - loss: 1.7580 - accuracy: 0.4754 - precision: 0.2703 - recall: 0.6667 - val_loss: 1.7532 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/50
# 4/4 [==============================] - 0s 23ms/step - loss: 1.8110 - accuracy: 0.4262 - precision: 0.2619 - recall: 0.7333 - val_loss: 1.7234 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.6674 - accuracy: 0.4918 - precision: 0.2778 - recall: 0.6667 - val_loss: 1.6956 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7046 - accuracy: 0.4918 - precision: 0.2647 - recall: 0.6000 - val_loss: 1.6696 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.6637 - accuracy: 0.4426 - precision: 0.2121 - recall: 0.4667 - val_loss: 1.6452 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.5992 - accuracy: 0.5082 - precision: 0.2857 - recall: 0.6667 - val_loss: 1.6224 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/50
# 4/4 [==============================] - 0s 24ms/step - loss: 1.5546 - accuracy: 0.5902 - precision: 0.3333 - recall: 0.6667 - val_loss: 1.6007 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/50
# 4/4 [==============================] - 0s 26ms/step - loss: 1.5794 - accuracy: 0.5410 - precision: 0.2759 - recall: 0.5333 - val_loss: 1.5798 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/50
# 4/4 [==============================] - 0s 24ms/step - loss: 1.5463 - accuracy: 0.6230 - precision: 0.3182 - recall: 0.4667 - val_loss: 1.5597 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.5516 - accuracy: 0.4754 - precision: 0.2424 - recall: 0.5333 - val_loss: 1.5408 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.4749 - accuracy: 0.5574 - precision: 0.3000 - recall: 0.6000 - val_loss: 1.5230 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/50
# 4/4 [==============================] - 0s 24ms/step - loss: 1.4815 - accuracy: 0.5902 - precision: 0.3214 - recall: 0.6000 - val_loss: 1.5060 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/50
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4532 - accuracy: 0.4754 - precision: 0.2571 - recall: 0.6000 - val_loss: 1.4898 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/50
# 4/4 [==============================] - 0s 26ms/step - loss: 1.4465 - accuracy: 0.5902 - precision: 0.2727 - recall: 0.4000 - val_loss: 1.4746 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/50
# 4/4 [==============================] - 0s 31ms/step - loss: 1.4204 - accuracy: 0.5410 - precision: 0.2903 - recall: 0.6000 - val_loss: 1.4605 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3765 - accuracy: 0.6557 - precision: 0.4062 - recall: 0.8667 - val_loss: 1.4469 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3857 - accuracy: 0.5902 - precision: 0.3438 - recall: 0.7333 - val_loss: 1.4341 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3450 - accuracy: 0.6066 - precision: 0.3636 - recall: 0.8000 - val_loss: 1.4220 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.4022 - accuracy: 0.5574 - precision: 0.2857 - recall: 0.5333 - val_loss: 1.4103 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.3491 - accuracy: 0.6393 - precision: 0.3333 - recall: 0.4667 - val_loss: 1.3991 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/50
# 4/4 [==============================] - 0s 23ms/step - loss: 1.2730 - accuracy: 0.7213 - precision: 0.4545 - recall: 0.6667 - val_loss: 1.3885 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.2800 - accuracy: 0.6393 - precision: 0.3871 - recall: 0.8000 - val_loss: 1.3784 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2685 - accuracy: 0.6721 - precision: 0.3913 - recall: 0.6000 - val_loss: 1.3689 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2602 - accuracy: 0.6557 - precision: 0.3929 - recall: 0.7333 - val_loss: 1.3596 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/50
# 4/4 [==============================] - 0s 26ms/step - loss: 1.2599 - accuracy: 0.6885 - precision: 0.4167 - recall: 0.6667 - val_loss: 1.3508 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1997 - accuracy: 0.7049 - precision: 0.4444 - recall: 0.8000 - val_loss: 1.3422 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2577 - accuracy: 0.7213 - precision: 0.4583 - recall: 0.7333 - val_loss: 1.3340 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1779 - accuracy: 0.8033 - precision: 0.5652 - recall: 0.8667 - val_loss: 1.3263 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2163 - accuracy: 0.6230 - precision: 0.3462 - recall: 0.6000 - val_loss: 1.3190 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1809 - accuracy: 0.7213 - precision: 0.4545 - recall: 0.6667 - val_loss: 1.3117 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2202 - accuracy: 0.6393 - precision: 0.3600 - recall: 0.6000 - val_loss: 1.3044 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2123 - accuracy: 0.7377 - precision: 0.4737 - recall: 0.6000 - val_loss: 1.2972 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1839 - accuracy: 0.6557 - precision: 0.3636 - recall: 0.5333 - val_loss: 1.2909 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1507 - accuracy: 0.6885 - precision: 0.4231 - recall: 0.7333 - val_loss: 1.2849 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1611 - accuracy: 0.6393 - precision: 0.3333 - recall: 0.4667 - val_loss: 1.2793 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.1217 - accuracy: 0.7213 - precision: 0.4583 - recall: 0.7333 - val_loss: 1.2739 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1407 - accuracy: 0.7213 - precision: 0.4500 - recall: 0.6000 - val_loss: 1.2685 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1529 - accuracy: 0.7377 - precision: 0.4800 - recall: 0.8000 - val_loss: 1.2630 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# 3/3 [==============================] - 0s 3ms/step
#
# Training Set Evaluation:
# Threshold: 0.00, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.01, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.02, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.03, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.04, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.05, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.06, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.07, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.08, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.09, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.10, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.11, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.12, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.13, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.14, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.15, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.16, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.17, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.18, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.19, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.20, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.21, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.22, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.23, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.24, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.25, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.26, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.27, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.28, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.29, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.30, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.31, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.32, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.33, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.34, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.35, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.36, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.37, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.38, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.39, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.40, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.41, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.42, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.43, Sensitivity: 1.00, Specificity: 0.10, Accuracy: 0.35
# Threshold: 0.44, Sensitivity: 0.79, Specificity: 0.65, Accuracy: 0.69
# Threshold: 0.45, Sensitivity: 0.32, Specificity: 0.96, Accuracy: 0.78
# Threshold: 0.46, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.47, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.48, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.49, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.50, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.51, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.52, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.53, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.54, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.55, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.56, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.57, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.58, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.59, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.60, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.61, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.62, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.63, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.64, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.65, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.66, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.67, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.68, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.69, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.70, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.71, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.72, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.73, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.74, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.75, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.76, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.77, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.78, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.79, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.80, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.81, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.82, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.83, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.84, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.85, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.86, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.87, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.88, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.89, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.90, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.91, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.92, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.93, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.94, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.95, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.96, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.97, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.98, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.99, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 1.00, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
#
# Best Threshold from Training Set: 0.5
# 1/1 [==============================] - 0s 30ms/step
#
# Test Set Evaluation at Best Threshold (0.5):
# Sensitivity: 0.00
# Specificity: 1.00
# Accuracy: 0.67
#
# Test Set Evaluation for Each Threshold:
# Threshold: 0.00, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.01, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.02, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.03, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.04, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.05, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.06, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.07, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.08, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.09, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.10, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.11, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.12, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.13, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.14, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.15, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.16, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.17, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.18, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.19, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.20, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.21, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.22, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.23, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.24, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.25, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.26, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.27, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.28, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.29, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.30, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.31, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.32, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.33, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.34, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.35, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.36, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.37, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.38, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.39, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.40, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.41, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.42, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.33
# Threshold: 0.43, Sensitivity: 1.00, Specificity: 0.08, Accuracy: 0.39
# Threshold: 0.44, Sensitivity: 0.50, Specificity: 0.58, Accuracy: 0.56
# Threshold: 0.45, Sensitivity: 0.17, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.46, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.47, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.48, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.49, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.50, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.51, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.52, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.53, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.54, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.55, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.56, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.57, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.58, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.59, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.60, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.61, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.62, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.63, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.64, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.65, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.66, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.67, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.68, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.69, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.70, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.71, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.72, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.73, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.74, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.75, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.76, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.77, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.78, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.79, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.80, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.81, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.82, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.83, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.84, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.85, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.86, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.87, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.88, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.89, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.90, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.91, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.92, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.93, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.94, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.95, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.96, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.97, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.98, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 0.99, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67
# Threshold: 1.00, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.67

# %%
Training: Threshold: 0.51, Sensitivity: 0.71, Specificity: 0.81, Accuracy: 0.78
Test: Threshold: 0.51, Sensitivity: 0.33, Specificity: 0.79, Accuracy: 0.71
