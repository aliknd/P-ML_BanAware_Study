# %%
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the dataset
data = pd.read_csv("10.csv")

# Separate data into different dataframes based on data types
spo2_data = data[data['data_type'] == 'spo2'].copy()
heart_rate_data = data[data['data_type'] == 'hr'].copy()
steps_data = data[data['data_type'] == 'steps'].copy()
hrv_data = data[data['data_type'] == 'hrv'].copy()
br_data = data[data['data_type'] == 'br'].copy()
sleep_data = data[data['data_type'] == 'sleep'].copy()

# Convert timestamps to datetime format for each dataframe
spo2_data['time'] = pd.to_datetime(spo2_data['time'])
heart_rate_data['time'] = pd.to_datetime(heart_rate_data['time'])
steps_data['time'] = pd.to_datetime(steps_data['time'])
hrv_data['time'] = pd.to_datetime(hrv_data['time'])
br_data['time'] = pd.to_datetime(br_data['time'])
sleep_data['time'] = pd.to_datetime(sleep_data['time'])

# Sort dataframes based on time and their respective formats
spo2_data.sort_values(by='time', inplace=True)
heart_rate_data.sort_values(by='time', inplace=True)
steps_data.sort_values(by='time', inplace=True)
hrv_data.sort_values(by='time', inplace=True)
br_data.sort_values(by='time', inplace=True)
sleep_data.sort_values(by='time', inplace=True)

# %%
heart_rate_data=heart_rate_data[['value', 'time']]

# %%
heart_rate_data
# Out:
#       value                      time
# 2        70 2023-11-23 00:00:00+00:00
# 3        75 2023-11-23 00:01:00+00:00
# 4        78 2023-11-23 00:02:00+00:00
# 5        74 2023-11-23 00:03:00+00:00
# 6        76 2023-11-23 00:04:00+00:00
# ...     ...                       ...
# 53937    62 2023-12-20 23:55:00+00:00
# 53938    63 2023-12-20 23:56:00+00:00
# 53939    63 2023-12-20 23:57:00+00:00
# 53940    62 2023-12-20 23:58:00+00:00
# 53941    63 2023-12-20 23:59:00+00:00
#
# [38041 rows x 2 columns]

# %%
steps_data=steps_data[['value', 'time']]

# %%
steps_data
# Out:
#       value                      time
# 39       16 2023-11-23 00:36:00+00:00
# 73        7 2023-11-23 01:10:00+00:00
# 76        4 2023-11-23 01:12:00+00:00
# 78       11 2023-11-23 01:13:00+00:00
# 525      35 2023-11-23 06:09:00+00:00
# ...     ...                       ...
# 53887    25 2023-12-20 23:15:00+00:00
# 53890    23 2023-12-20 23:16:00+00:00
# 53891     5 2023-12-20 23:17:00+00:00
# 53896     4 2023-12-20 23:20:00+00:00
# 53908     7 2023-12-20 23:31:00+00:00
#
# [5810 rows x 2 columns]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# Load use and non-use data
use_data = pd.read_csv('ID10_Use.csv')
non_use_data = pd.read_csv('ID10_None.csv')

# Print the columns to check the available column names
print("Use Data Columns:", use_data.columns)
print("Non-Use Data Columns:", non_use_data.columns)

# Filter rows with 'Melon' in the substance_fruit_label column
use_data = use_data[use_data['substance_fruit_label'] == 'Carrot']

# Standardize the timestamp format in 'hawaii_use_time'
use_data['hawaii_use_time'] = use_data['hawaii_use_time'].apply(lambda x: x.split('.')[0] if '.' in x else x)
use_data['hawaii_use_time'] = pd.to_datetime(use_data['hawaii_use_time'], format='%Y-%m-%d %H:%M:%S').dt.tz_localize(None)

# Convert timestamps to ensure they are timezone-naive for non-use data
non_use_data['hawaii_createdat_time'] = pd.to_datetime(non_use_data['hawaii_createdat_time'], format='%Y-%m-%d %H:%M:%S').dt.tz_localize(None)

# Ensure heart rate and steps data use the same timezone-naive datetime index
heart_rate_data['time'] = pd.to_datetime(heart_rate_data['time']).dt.tz_localize(None)
steps_data['time'] = pd.to_datetime(steps_data['time']).dt.tz_localize(None)

heart_rate_data.set_index('time', inplace=True)
steps_data.set_index('time', inplace=True)

# Convert the 'value' column to numeric, coercing errors
heart_rate_data['value'] = pd.to_numeric(heart_rate_data['value'], errors='coerce')
steps_data['value'] = pd.to_numeric(steps_data['value'], errors='coerce')

# Remove duplicate timestamps
heart_rate_data = heart_rate_data[~heart_rate_data.index.duplicated(keep='first')]
steps_data = steps_data[~steps_data.index.duplicated(keep='first')]

# Reindex and forward fill to handle missing data
heart_rate_data = heart_rate_data.reindex(pd.date_range(start=heart_rate_data.index.min(), end=heart_rate_data.index.max(), freq='min'), method='ffill')
steps_data = steps_data.reindex(pd.date_range(start=steps_data.index.min(), end=steps_data.index.max(), freq='min'), method='ffill').fillna(0)

# Initialize the StandardScaler
scaler = StandardScaler()

def process_label_data(label_data, heart_rate_data, steps_data, scaler, time_column):
    results = []
    for _, row in label_data.iterrows():
        timestamp = row[time_column]
        lower_bound = timestamp - pd.Timedelta(hours=1)
        upper_bound = timestamp + pd.Timedelta(hours=1)

        # Extract data within the window
        hr_window = heart_rate_data.loc[lower_bound:upper_bound]
        steps_window = steps_data.loc[lower_bound:upper_bound]

        # Resample and calculate mean every 4 minutes to get 30 points
        hr_means = hr_window.resample('4min').mean().iloc[:30]  # Ensure 30 data points
        steps_means = steps_window.resample('4min').mean().iloc[:30]

        if len(hr_means) == 30 and len(steps_means) == 30:
            # Standardize the means
            hr_scaled = scaler.fit_transform(hr_means.values.reshape(-1, 1))
            steps_scaled = scaler.fit_transform(steps_means.values.reshape(-1, 1))

            results.append({
                'timestamp': timestamp,
                'heart_rate_means': hr_scaled.flatten().tolist(),
                'steps_means': steps_scaled.flatten().tolist()
            })

    return pd.DataFrame(results)

# Process use and non-use labels
use_features = process_label_data(use_data, heart_rate_data, steps_data, scaler, 'hawaii_use_time')
non_use_features = process_label_data(non_use_data, heart_rate_data, steps_data, scaler, 'hawaii_createdat_time')

# Output results
print("Use Features Data:")
print(use_features.head())
print("Non-Use Features Data:")
print(non_use_features.head())
# Out:
# Use Data Columns: Index(['id', 'substance_fruit_label', 'crave_use_none_label',
#        'crave_use_none_value', 'user_id', 'created_at',
#        'hawaii_createdat_time', 'hawaii_use_time'],
#       dtype='object')
# Non-Use Data Columns: Index(['id', 'substance_fruit_label', 'crave_use_none_label',
#        'crave_use_none_value', 'user_id', 'created_at',
#        'hawaii_createdat_time'],
#       dtype='object')
# Use Features Data:
#             timestamp                                   heart_rate_means  \
# 0 2023-11-24 21:31:03  [-0.3561901304220234, 0.41164488126617127, 0.4...
# 1 2023-11-27 14:00:22  [-0.922313398251912, -1.617563757747284, -1.26...
# 2 2023-11-27 22:18:35  [-0.9353199394922614, -0.8201192431325107, -0....
# 3 2023-11-30 18:24:19  [-0.6158914648912189, -0.797629929941087, -0.8...
# 4 2023-12-01 22:47:57  [0.24480951951102636, -0.12012392572280124, -1...
#
#                                          steps_means
# 0  [-0.5675944607325412, -0.7221587616884526, -0....
# 1  [-0.8357245162624579, -0.8357245162624579, -0....
# 2  [0.7927742120742489, -0.6716433746535541, -0.6...
# 3  [-0.6175926581460746, -0.6175926581460746, -0....
# 4  [2.2310112699967584, 2.338228471598525, -0.958...
# Non-Use Features Data:
#             timestamp                                   heart_rate_means  \
# 0 2023-11-28 15:09:42  [1.1164115773804473, 0.2702891187342125, 1.045...
# 1 2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# 2 2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# 3 2023-11-29 13:46:17  [0.5720173895929694, 0.10400316174417626, 0.57...
# 4 2023-11-29 17:02:21  [-0.7464240342806893, -1.7322670984249973, -0....
#
#                                          steps_means
# 0  [1.1358660206519509, 1.1358660206519509, 1.135...
# 1  [0.40009983687523415, 0.40009983687523415, 0.4...
# 2  [0.40009983687523415, 0.40009983687523415, 0.4...
# 3  [-1.8901033586340465, -1.8901033586340465, -1....
# 4  [-0.8240793061668402, -0.8240793061668402, -0....

# %%
# Print the shape of the use features data
print("Shape of Use Features Data:", use_features.shape)

# Print the shape of the non-use features data
print("Shape of Non-Use Features Data:", non_use_features.shape)
# Out:
# Shape of Use Features Data: (21, 3)
# Shape of Non-Use Features Data: (61, 3)

# %%
import pandas as pd

# Adding label columns
use_features['state'] = 'use'
use_features['state_val'] = 1

non_use_features['state'] = 'non_use'
non_use_features['state_val'] = 0

# Combining the dataframes
combined_data = pd.concat([use_features, non_use_features])

# Converting timestamps to datetime and sorting
combined_data['timestamp'] = pd.to_datetime(combined_data['timestamp'])
combined_data_sorted = combined_data.sort_values(by='timestamp').reset_index(drop=True)

# This combined_data_sorted is now ready for use in your neural network model
print(combined_data_sorted)
# Out:
#              timestamp                                   heart_rate_means  \
# 0  2023-11-24 21:31:03  [-0.3561901304220234, 0.41164488126617127, 0.4...
# 1  2023-11-27 14:00:22  [-0.922313398251912, -1.617563757747284, -1.26...
# 2  2023-11-27 22:18:35  [-0.9353199394922614, -0.8201192431325107, -0....
# 3  2023-11-28 15:09:42  [1.1164115773804473, 0.2702891187342125, 1.045...
# 4  2023-11-29 09:30:29  [-1.6865439786173657, -1.4703203916151393, -1....
# ..                 ...                                                ...
# 77 2023-12-19 15:14:17  [-2.254171873579388, -2.0163691264765076, -1.7...
# 78 2023-12-19 20:44:10  [-0.6000189833388985, 0.6528615642579431, 1.49...
# 79 2023-12-19 21:04:47  [2.7477021384420746, 3.377959771807056, 2.4823...
# 80 2023-12-20 18:42:51  [0.06869206174208, 0.5838825248076779, 0.47348...
# 81 2023-12-20 18:42:51  [0.06869206174208, 0.5838825248076779, 0.47348...
#
#                                           steps_means    state  state_val
# 0   [-0.5675944607325412, -0.7221587616884526, -0....      use          1
# 1   [-0.8357245162624579, -0.8357245162624579, -0....      use          1
# 2   [0.7927742120742489, -0.6716433746535541, -0.6...      use          1
# 3   [1.1358660206519509, 1.1358660206519509, 1.135...  non_use          0
# 4   [0.40009983687523415, 0.40009983687523415, 0.4...  non_use          0
# ..                                                ...      ...        ...
# 77  [-0.8957298910702948, -0.8957298910702948, -0....      use          1
# 78  [-0.8976196836876423, -0.8976196836876423, -0....  non_use          0
# 79  [-1.239678371558235, -1.239678371558235, -2.90...  non_use          0
# 80  [1.1185452796660895, -0.2411913844721381, 1.32...  non_use          0
# 81  [1.1185452796660895, -0.2411913844721381, 1.32...  non_use          0
#
# [82 rows x 5 columns]

# %%
import tensorflow as tf

# Load pretrained models
encoder_hr = tf.keras.models.load_model('heart_rate_encoder')
encoder_steps = tf.keras.models.load_model('steps_encoder')
# Out:
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:178: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np

# Function to generate embeddings using the loaded models
def generate_embeddings(hr_data, steps_data, encoder_hr, encoder_steps):
    # Convert lists to numpy arrays and ensure they are in the correct shape
    hr_data = np.array(hr_data.tolist())
    steps_data = np.array(steps_data.tolist())

    # Reshape data if required by the model, assuming the model expects shape (samples, features)
    if hr_data.ndim == 1:
        hr_data = hr_data.reshape(-1, 1)
    if steps_data.ndim == 1:
        steps_data = steps_data.reshape(-1, 1)

    # Generate embeddings
    hr_embeddings = encoder_hr.predict(hr_data)
    steps_embeddings = encoder_steps.predict(steps_data)

    return hr_embeddings, steps_embeddings

# Use the function with your data
hr_embeddings, steps_embeddings = generate_embeddings(
    combined_data_sorted['heart_rate_means'],
    combined_data_sorted['steps_means'],
    encoder_hr,
    encoder_steps
)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, auc
from sklearn.metrics import recall_score, precision_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

# Combine the heart rate and steps embeddings
combined_embeddings = np.concatenate([hr_embeddings, steps_embeddings], axis=1)

# Labels from your existing DataFrame
labels = combined_data_sorted['state_val'].values

# Calculate class weights
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(combined_embeddings, labels, test_size=0.2, random_state=42)

# Define the model with regularization and batch normalization
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(16, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy', Precision(), Recall()])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    class_weight=class_weight_dict,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate thresholds on training set
probabilities_train = model.predict(X_train)
thresholds = np.arange(0, 1.01, 0.01)

# Store training results
training_results = []

print("\nTraining Set Evaluation:")
for threshold in thresholds:
    predicted_classes = (probabilities_train > threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_train, predicted_classes).ravel()
    recall = tp / (tp + fn)  # Sensitivity
    specificity = tn / (tn + fp)  # Specificity
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    training_results.append((threshold, recall, specificity, accuracy))
    print(f"Threshold: {threshold:.2f}, Sensitivity: {recall:.2f}, Specificity: {specificity:.2f}, Accuracy: {accuracy:.2f}")

# Convert training results to DataFrame for easy viewing
training_results_df = pd.DataFrame(training_results, columns=['Threshold', 'Sensitivity', 'Specificity', 'Accuracy'])

# Select best threshold based on a specific criterion
# Here, we select the threshold with the highest sensitivity while keeping specificity above 0.5
best_threshold_row = training_results_df[(training_results_df['Sensitivity'] > 0.9) & (training_results_df['Specificity'] > 0.5)]
if not best_threshold_row.empty:
    best_threshold = best_threshold_row.iloc[0]['Threshold']
else:
    best_threshold = 0.5  # Default threshold if criteria is not met

print(f"\nBest Threshold from Training Set: {best_threshold}")

# Evaluate the best threshold on the test set
probabilities_test = model.predict(X_test)
predicted_classes_test = (probabilities_test > best_threshold).astype(int)
tn, fp, fn, tp = confusion_matrix(y_test, predicted_classes_test).ravel()
recall_test = tp / (tp + fn)  # Sensitivity
specificity_test = tn / (tn + fp)  # Specificity
accuracy_test = (tp + tn) / (tp + tn + fp + fn)

print(f"\nTest Set Evaluation at Best Threshold ({best_threshold}):")
print(f"Sensitivity: {recall_test:.2f}")
print(f"Specificity: {specificity_test:.2f}")
print(f"Accuracy: {accuracy_test:.2f}")

# Store test results
test_results = []

for threshold in thresholds:
    predicted_classes = (probabilities_test > threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, predicted_classes).ravel()
    recall = tp / (tp + fn)  # Sensitivity
    specificity = tn / (tn + fp)  # Specificity
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    test_results.append((threshold, recall, specificity, accuracy))
    print(f"Threshold: {threshold:.2f}, Sensitivity: {recall:.2f}, Specificity: {specificity:.2f}, Accuracy: {accuracy:.2f}")

# Convert test results to DataFrame for easy viewing
test_results_df = pd.DataFrame(test_results, columns=['Threshold', 'Sensitivity', 'Specificity', 'Accuracy'])

# Find the threshold where specificity is around 0.9 and sensitivity is around 0.5
desired_specificity = 0.9
desired_sensitivity_range = (0.4, 0.6)  # Considering sensitivity around 0.5

filtered_results = test_results_df[
    (test_results_df['Specificity'] >= desired_specificity) & 
    (test_results_df['Sensitivity'] >= desired_sensitivity_range[0]) & 
    (test_results_df['Sensitivity'] <= desired_sensitivity_range[1])
]

# Print the filtered results
print("\nFiltered Thresholds with Specificity >= 0.9 and Sensitivity ~ 0.5:")
print(filtered_results)

# Plot the results for better visualization
plt.figure(figsize=(12, 6))
plt.plot(test_results_df['Threshold'], test_results_df['Sensitivity'], label='Sensitivity')
plt.plot(test_results_df['Threshold'], test_results_df['Specificity'], label='Specificity')
plt.plot(test_results_df['Threshold'], test_results_df['Accuracy'], label='Accuracy')
plt.axhline(y=0.9, color='r', linestyle='--', label='Desired Specificity (0.9)')
plt.axhline(y=0.5, color='g', linestyle='--', label='Desired Sensitivity (0.5)')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Sensitivity, Specificity, and Accuracy vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 3s 145ms/step - loss: 2.3773 - accuracy: 0.5690 - precision: 0.2222 - recall: 0.2667 - val_loss: 2.3009 - val_accuracy: 0.2857 - val_precision: 0.2500 - val_recall: 0.3333
# Epoch 2/50
# 4/4 [==============================] - 0s 20ms/step - loss: 2.4257 - accuracy: 0.4310 - precision: 0.1250 - recall: 0.2000 - val_loss: 2.2393 - val_accuracy: 0.1429 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
#
 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3943 - accuracy: 0.5690 - precision: 0.3438 - recall: 0.7333 - val_loss: 1.4422 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3803 - accuracy: 0.7414 - precision: 0.5000 - recall: 0.7333 - val_loss: 1.4306 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/50
# 4/4 [==============================] - 0s 31ms/step - loss: 1.4268 - accuracy: 0.6379 - precision: 0.3929 - recall: 0.7333 - val_loss: 1.4197 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.3508 - accuracy: 0.5690 - precision: 0.3214 - recall: 0.6000 - val_loss: 1.4091 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4162 - accuracy: 0.6034 - precision: 0.3182 - recall: 0.4667 - val_loss: 1.3988 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3339 - accuracy: 0.6724 - precision: 0.4231 - recall: 0.7333 - val_loss: 1.3886 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2895 - accuracy: 0.6552 - precision: 0.4074 - recall: 0.7333 - val_loss: 1.3789 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.2604 - accuracy: 0.6724 - precision: 0.4231 - recall: 0.7333 - val_loss: 1.3696 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/50
# 4/4 [==============================] - 0s 22ms/step - loss: 1.3119 - accuracy: 0.7241 - precision: 0.4762 - recall: 0.6667 - val_loss: 1.3608 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/50
# 4/4 [==============================] - 0s 21ms/step - loss: 1.2868 - accuracy: 0.5690 - precision: 0.3333 - recall: 0.6667 - val_loss: 1.3524 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2385 - accuracy: 0.6552 - precision: 0.4000 - recall: 0.6667 - val_loss: 1.3439 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3150 - accuracy: 0.5862 - precision: 0.3333 - recall: 0.6000 - val_loss: 1.3356 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2473 - accuracy: 0.6724 - precision: 0.4231 - recall: 0.7333 - val_loss: 1.3277 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1415 - accuracy: 0.7759 - precision: 0.5455 - recall: 0.8000 - val_loss: 1.3203 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1948 - accuracy: 0.6897 - precision: 0.4444 - recall: 0.8000 - val_loss: 1.3135 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2208 - accuracy: 0.6207 - precision: 0.3478 - recall: 0.5333 - val_loss: 1.3071 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/50
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1705 - accuracy: 0.6897 - precision: 0.4400 - recall: 0.7333 - val_loss: 1.3004 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1965 - accuracy: 0.7069 - precision: 0.4643 - recall: 0.8667 - val_loss: 1.2940 - val_accuracy: 0.5714 - val_precision: 0.5000 - val_recall: 0.3333
# Epoch 49/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2285 - accuracy: 0.6552 - precision: 0.4074 - recall: 0.7333 - val_loss: 1.2872 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/50
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1481 - accuracy: 0.7241 - precision: 0.4783 - recall: 0.7333 - val_loss: 1.2800 - val_accuracy: 0.4286 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# 3/3 [==============================] - 0s 6ms/step
#
# Training Set Evaluation:
# Threshold: 0.00, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.01, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.02, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.03, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.04, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.05, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.06, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.07, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.08, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.09, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.10, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.11, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.12, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.13, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.14, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.15, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.16, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.17, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.18, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.19, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.20, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.21, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.22, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.23, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.24, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.25, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.26, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.27, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.28, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.29, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.30, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.31, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.32, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.33, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.34, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.35, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.36, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.37, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.38, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.39, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.40, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.41, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.42, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.43, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.44, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.45, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.28
# Threshold: 0.46, Sensitivity: 1.00, Specificity: 0.04, Accuracy: 0.31
# Threshold: 0.47, Sensitivity: 1.00, Specificity: 0.04, Accuracy: 0.31
# Threshold: 0.48, Sensitivity: 1.00, Specificity: 0.19, Accuracy: 0.42
# Threshold: 0.49, Sensitivity: 1.00, Specificity: 0.38, Accuracy: 0.55
# Threshold: 0.50, Sensitivity: 0.72, Specificity: 0.85, Accuracy: 0.82
# Threshold: 0.51, Sensitivity: 0.44, Specificity: 0.98, Accuracy: 0.83
# Threshold: 0.52, Sensitivity: 0.17, Specificity: 1.00, Accuracy: 0.77
# Threshold: 0.53, Sensitivity: 0.11, Specificity: 1.00, Accuracy: 0.75
# Threshold: 0.54, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.55, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.56, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.57, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.58, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.59, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.60, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.61, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.62, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.63, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.64, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.65, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.66, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.67, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.68, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.69, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.70, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.71, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.72, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.73, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.74, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.75, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.76, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.77, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.78, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.79, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.80, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.81, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.82, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.83, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.84, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.85, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.86, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.87, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.88, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.89, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.90, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.91, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.92, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.93, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.94, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.95, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.96, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.97, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.98, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 0.99, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
# Threshold: 1.00, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.72
#
# Best Threshold from Training Set: 0.5
# 1/1 [==============================] - 0s 34ms/step
#
# Test Set Evaluation at Best Threshold (0.5):
# Sensitivity: 0.33
# Specificity: 0.64
# Accuracy: 0.59
# Threshold: 0.00, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.01, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.02, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.03, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.04, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.05, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.06, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.07, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.08, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.09, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.10, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.11, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.12, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.13, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.14, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.15, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.16, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.17, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.18, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.19, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.20, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.21, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.22, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.23, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.24, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.25, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.26, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.27, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.28, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.29, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.30, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.31, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.32, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.33, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.34, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.35, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.36, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.37, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.38, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.39, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.40, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.41, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.42, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.43, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.44, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.45, Sensitivity: 1.00, Specificity: 0.00, Accuracy: 0.18
# Threshold: 0.46, Sensitivity: 1.00, Specificity: 0.07, Accuracy: 0.24
# Threshold: 0.47, Sensitivity: 1.00, Specificity: 0.07, Accuracy: 0.24
# Threshold: 0.48, Sensitivity: 1.00, Specificity: 0.14, Accuracy: 0.29
# Threshold: 0.49, Sensitivity: 0.67, Specificity: 0.43, Accuracy: 0.47
# Threshold: 0.50, Sensitivity: 0.33, Specificity: 0.64, Accuracy: 0.59
# Threshold: 0.51, Sensitivity: 0.33, Specificity: 0.86, Accuracy: 0.76
# Threshold: 0.52, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.53, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.54, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.55, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.56, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.57, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.58, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.59, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.60, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.61, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.62, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.63, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.64, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.65, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.66, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.67, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.68, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.69, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.70, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.71, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.72, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.73, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.74, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.75, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.76, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.77, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.78, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.79, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.80, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.81, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.82, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.83, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.84, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.85, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.86, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.87, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.88, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.89, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.90, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.91, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.92, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.93, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.94, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.95, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.96, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.97, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.98, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 0.99, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
# Threshold: 1.00, Sensitivity: 0.00, Specificity: 1.00, Accuracy: 0.82
#
# Filtered Thresholds with Specificity >= 0.9 and Sensitivity ~ 0.5:
# Empty DataFrame
# Columns: [Threshold, Sensitivity, Specificity, Accuracy]
# Index: []
